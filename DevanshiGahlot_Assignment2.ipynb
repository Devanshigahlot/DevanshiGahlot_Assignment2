# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style

# %%
df=pd.read_csv("employee_data.csv",sep="\t")

# %%
df
# Out:
#      age    employment_type  salary      education       marital-status  \
# 0     39          State-gov   77516      Bachelors        Never-married
# 1     50   Self-emp-not-inc   83311      Bachelors   Married-civ-spouse
# 2     38            Private  215646        HS-grad             Divorced
# 3     53            Private  234721           11th   Married-civ-spouse
# 4     28            Private  338409      Bachelors   Married-civ-spouse
# ..   ...                ...     ...            ...                  ...
# 973   37            Private  200153        HS-grad   Married-civ-spouse
# 974   44            Private   32185        HS-grad        Never-married
# 975   25            Private  178326   Some-college        Never-married
# 976   21            Private  255957   Some-college        Never-married
# 977   40          State-gov  188693        Masters   Married-civ-spouse
#
#        relationship   Gender  hours_per_week
# 0     Not-in-family     Male              40
# ...

# %% [markdown]
# # 1.Identify Categorical variables & Continuous Variables

# %%
#To display all the categorical columns in the dataset:-
df.select_dtypes(exclude="number")
# Out:
#        employment_type      education       marital-status    relationship  \
# 0            State-gov      Bachelors        Never-married   Not-in-family
# 1     Self-emp-not-inc      Bachelors   Married-civ-spouse         Husband
# 2              Private        HS-grad             Divorced   Not-in-family
# 3              Private           11th   Married-civ-spouse         Husband
# 4              Private      Bachelors   Married-civ-spouse            Wife
# ..                 ...            ...                  ...             ...
# 973            Private        HS-grad   Married-civ-spouse         Husband
# 974            Private        HS-grad        Never-married       Unmarried
# 975            Private   Some-college        Never-married   Not-in-family
# 976            Private   Some-college        Never-married   Not-in-family
# 977          State-gov        Masters   Married-civ-spouse         Husband
#
#       Gender
# 0       Male
# 1       Male
# 2       Male
# ...

# %%
#To display all the continous columns in the dataset:-
df.select_dtypes(include="number")
# Out:
#      age  salary  hours_per_week
# 0     39   77516              40
# 1     50   83311              13
# 2     38  215646              40
# 3     53  234721              40
# 4     28  338409              40
# ..   ...     ...             ...
# 973   37  200153              40
# 974   44   32185              70
# 975   25  178326              40
# 976   21  255957              40
# 977   40  188693              35
#
# [978 rows x 3 columns]

# %% [markdown]
# # 2.Carry on a Univariate analysis on all the Variables/Fields. User bar plots for Categorical Variables & histogram or line plot for Continuous ones. Label the plot and axis clearly for intuitive understanding. Mention observations drawn from each Univariate plot

# %% [markdown]
# # CATEGORICAL VARIABLES

# %%
#Plotting barplot for categorical data("employment_type")
ax=df["employment_type"].value_counts().plot(kind="bar")
ax.set_title("EMPLOYMENT CLASSIFICATION")
ax.set_xlabel("employment type")
ax.set_ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# INFERENCES DRAWN FROM THE ABOVE GRAPH:-
# *More than 650 employees are working in the private sector
# *Minimum employees are working in the Federal-Gov sector

# %%
#Plotting barplot for categorical data("education")
ax=df["education"].value_counts().plot(kind="bar")
ax.set_title("EDUCATION CLASSIFICATION")
ax.set_xlabel("education type")
ax.set_ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# INFERENCES DRAWN FROM THE ABOVE GRAPH:-
# *Maximum number of employees are HS-graduate
# *Minimum number of employees have completed their education till Preschool

# %%
#Plotting barplot for categorical data("marital-status")
ax=df["marital-status"].value_counts().plot(kind="bar")
ax.set_title("MARITAL STATUS CLASSIFICATION")
ax.set_xlabel("marital status type")
ax.set_ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# INFERENCES DRAWN FROM THE ABOVE GRAPH:-
# *More than 400 employees are "Married-civ-spouse"
# *Least employees are having the marital status as "Married-AF-spouse"

# %%
#Plotting barplot for categorical data("relationship")
ax=df["relationship"].value_counts().plot(kind="bar")
ax.set_title("RELATIONSHIP CLASSIFICATION")
ax.set_xlabel("relationship type")
ax.set_ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# INFERENCES DRAWN FROM THE ABOVE GRAPH:-
# *More than 350 employees are from "Husband" category
# *Less than 50 employees are having the relationship status as "Other-Relative"

# %%
#Plotting barplot for categorical data("gender")
ax=df["Gender"].value_counts().plot(kind="bar")
ax.set_title("GENDER CLASSIFICATION")
ax.set_xlabel("gender type")
ax.set_ylabel("frequency")
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# INFERENCES DRAWN FROM THE ABOVE GRAPH:-
# *More than 600 employees working are of "Male" gender
# *About 300 employees are of "Female" gender

# %% [markdown]
# # CONTINUOUS VARIABLES

# %%
#Plotting Histogram plot for continuous data("age")
df["age"].hist()
plt.xlabel("age")
plt.ylabel("frequency")
plt.title("AGE CLASSIFICATION")
plt.show()

# %% [markdown]
# INFERENCES DRAWN FROM THE ABOVE GRAPH:-
# *More than 180 employees are between the age group[32-46]
# *Minimum number of employees are from the age groupb between [0-25]

# %%
#Plotting Histogram plot for continuous data("salary")
df["salary"].hist()
plt.xlabel("salary")
plt.ylabel("frequency")
plt.title("SALARY CLASSIFICATION")
plt.show()

# %% [markdown]
# INFERENCES DRAWN FROM THE ABOVE GRAPH:-
# *Approx 400 employees are having their salary [0.1-0.2] of le6.
# *Minimum number of employees are having their salary between[0.4-0.7]of le6.
# *Average number of employeees are having their salary between [0.2-0.3] of le6.

# %%
#Plotting barplot for continuous data("hours_per_week")
df["hours_per_week"].hist()
plt.xlabel("hours_per_week")
plt.ylabel("frequency")
plt.title("HOURS_PER_WEEK CLASSIFICATION")
plt.show()

# %% [markdown]
# INFERENCES DRAWN FROM THE ABOVE GRAPH:-
# *Maximum number of employees are working [30-40] hours per week
# *Minimum number of employees are working [80-100] hours per week

# %% [markdown]
# # 3.Show a bivariate analysis between Salary and hour_per_week.Choose a plot of your choice. Mention the inferences drawn

# %%
plt.scatter(df["salary"],df["hours_per_week"],c="red")
plt.title("BIVARITE ANALYSIS BETWEEN SALARY AND HOURS_PER_WEEK")
plt.xlabel("Salary")
plt.ylabel("Hours_per_week")
plt.show()

# %% [markdown]
# INFERENCES DRAWN FROM THE ABOVE GRAPH:-
# *Employees who are between the age group[40-65] are earning a fairly high price than compare to the employees of the more than this age group.

# %% [markdown]
# # 4.For each Education type , showcase the distribution of Salary .Use Seaborn Facetgrid & Line plot.Identify the key observations and mention them

# %%
fg=sns.FacetGrid(df,col="education",col_wrap=4)
fg.map(sns.lineplot,"salary","education")
plt.show()

# %% [markdown]
# INFERENCES DRAWN FROM THE ABOVE GRAPHS:-
# *Employees who have completed their bachelors are having the salary distribution from [0.0-0.6] of le6
# *Employees who have completed their HS-grad are having the salary distribution from [0.0-0.7] of le6
# *Employees who have completed their 11th are having the salary distribution from [0.0-0.5] of le6
# *Employees who have completed their Masters are having the salary distribution from [0.0-0.4] of le6
# *Employees who have completed their 9th are having the salary distribution from [0.1-0.5] of le6
# *Employees who have completed their Some-College are having the salary distribution from [0.0-1.0] of le6
# *Employees who have completed their Assoc-acdm are having the salary distribution from [0.0-0.35] of le6
# *Employees who have completed their Assoc-voc are having the salary distribution from [0.0-0.4] of le6
# *Employees who have completed their 7th-8th are having the salary distribution from [0.0-0.41] of le6
# *Employees who have completed their Doctorate are having the salary distribution from [0.1-0.4] of le6
# *Employees who have completed their Prof-School are having the salary distribution from [0.0-0.2] of le6
# *Employees who have completed their 5th-6th are having the salary distribution from [0.2-0.4] of le6
# *Employees who have completed their 10th are having the salary distribution from [0.0-0.5] of le6
# *Employees who have completed their 1st-4th are having the salary distribution from [0.01-0.4] of le6
# *Employees who have completed their Preschool are having the salary distribution from [0.08-0.21] of le6
# *Employees who have completed their 12th are having the salary distribution from [0.05-0.3] of le6

# %% [markdown]
# # 5.Categorizing each Gender & Relationship status (combination of all values) , plot the hours_per_week worked.Choose appropriate plots.Mention the inferences drawn

# %%
fg=sns.FacetGrid(df,col="Gender",hue="relationship")
fg.map(plt.scatter,"hours_per_week","relationship").add_legend()

# %% [markdown]
# INFERENCES DRAWN FROM THE ABOVE GRAPH:-
# *Males who belong to the "Other-Relative" relationship works more hours per week than compare to the female of the same relationship status.
# *Males who belong to the "Unmarried" relationship works more hours per week than compare to the female of the same relationship status.
# *Males who belong to the "Own-Child" relationship works more hours per week than compare to the female of the same relationship status.
# *Males who belong to the "Wife" relationship works very very less hours per week than compare to the female of the same relationship status.
# *Males who belong to the "Husband" relationship works the highest hours per week than compare to the female of the same relationship status and also compare to the other relationship status in the same gender category and in the different gender category as well.
# *Males who belong to the "Not-in-Family" relationship works less hours per week than compare to the female of the same relationship status.

# %% [markdown]
# # 6.How many Males that have Marital status ‘Married-civ-spouse’ are earning above 150,000 ?

# %%
#First I have filterred the data according to the salary criteria:-
new=df.loc[(df["salary"]>150000)]

#After that I have grouped the data on the basis of marital-status and gender:-
new_1=new.groupby(["marital-status","Gender"])["Gender"].count()
print(new_1)
print(" ")
print(" ")

#After the grouping I have added the indexing to make it more accessible:-
new_1=new.groupby(["marital-status","Gender"], as_index=False)["Gender"].count()
print(new_1)
print(" ")

#Now by the help of the inde3xing I have found the answer to the given question:-
new_1.loc[[4],["marital-status","Gender"]]
# Out:
# marital-status          Gender
#  Divorced                Female     44
#                          Male       35
#  Married-AF-spouse       Female      1
#  Married-civ-spouse      Female     34
#                          Male      226
#  Married-spouse-absent   Female      6
#                          Male        5
#  Never-married           Female     90
#                          Male      138
#  Separated               Female     10
#                          Male       11
#  Widowed                 Female     16
#                          Male        2
# Name: Gender, dtype: int64
#
#
#             marital-status  Gender
# 0                 Divorced      44
# 1                 Divorced      35
# 2        Married-AF-spouse       1
# 3       Married-civ-spouse      34
# 4       Married-civ-spouse     226
# 5    Married-spouse-absent       6
# 6    Married-spouse-absent       5
# 7            Never-married      90
# 8            Never-married     138
# ...

# %% [markdown]
# # 7.Are Divorced Individuals of higher age compared to Individuals that are Not-in-family ? Using mean as a measure , answer the above question & mention the respective age of the two groups.

# %%
div=df.groupby(["marital-status"],as_index=False)["age"].mean()
print(div.loc[[0],["marital-status","age"]])
print(" ")
nif=df.groupby(["relationship"],as_index=False)["age"].mean()
print(nif.loc[[1],["relationship","age"]])
# Out:
#   marital-status        age
# 0       Divorced  42.030769
#
#      relationship        age
# 1   Not-in-family  37.485185
